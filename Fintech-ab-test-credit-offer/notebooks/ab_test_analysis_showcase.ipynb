# %% [markdown]
# # A/B-test analysis showcase
#
# Этот ноутбук показывает полный walkthrough проекта: от загрузки данных до итоговой продуктовой рекомендации.

# %%
from pathlib import Path
import pandas as pd

repo_root = Path('..').resolve()
raw_path = repo_root / 'data' / 'raw' / 'data_raw_fintech_credit_offer_20000.csv'
processed_path = repo_root / 'data' / 'processed'
raw_path

# %% [markdown]
# ## 1. Load raw events

# %%
events = pd.read_csv(raw_path, parse_dates=['dt'])
events.head()

# %% [markdown]
# ## 2. Quality checks

# %%
pd.read_csv(processed_path / 'quality_checks.csv')

# %% [markdown]
# ## 3. Event mix

# %%
pd.read_csv(processed_path / 'event_mix_by_group.csv')

# %% [markdown]
# ## 4. User-day funnel

# %%
user_day = pd.read_csv(processed_path / 'user_day_funnel.csv')
user_day.head()

# %% [markdown]
# ## 5. User-level metrics

# %%
user_level = pd.read_csv(processed_path / 'user_level_metrics.csv')
user_level.head()

# %% [markdown]
# ## 6. Group comparison

# %%
comparison = pd.read_csv(processed_path / 'ab_results.csv')
comparison

# %% [markdown]
# ## 7. MDE and sample size

# %%
pd.read_csv(processed_path / 'sample_size_recommendation.csv')

# %% [markdown]
# ## 8. Interpretation
#
# - Primary metric: `CR_apply`
# - В анализируемых данных test > control.
# - При этом MDE = 2.5% делает исходный 7-дневный дизайн слишком слабым для строгого confirmatory вывода на реальном трафике.
